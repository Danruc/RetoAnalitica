# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(0)
import seaborn as sns

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %% [markdown]
# # Objetivo 1

# %%
df = pd.read_csv("covid19_tweets.csv")
newdf = df.copy()
newdf = newdf.drop(['user_name','user_location','user_description','user_created','user_verified','date','text','hashtags','source','is_retweet'], axis=1)

# %%
import re
def clean_1(s):
    s = s.replace('ðŸž', "")
    s = s.replace('ðŸ¤·â€â™', "")
    s = s.replace("ðŸ”´", "")
    s = s.replace("€™", "")
    s = s.replace("ƒ¼", "")
    s = s.replace("â€˜", "")
    s = s.replace("â€™", "")
    s = s.replace("ðŸ˜˜", "")
    s = s.replace("ðŸ”Š", "")
    s = s.replace("&amp;", "&")
    s = s.replace("ðŸ§©", "")
    s = s.replace(":", "")
    s = s.replace(";", "")
    s = s.replace("#", "")
    s = s.replace("'", "")
    s = s.replace("|", "")
    s = s.replace("//", "")
    s = s.replace('📍',"")
    s = s.replace('🏫',"")
    s = s.replace('💯',"")
    s = s.replace('🧵',"")
    s = s.replace('🔊',"")
    s = s.replace("●", "")
    s = s.replace("❤️", "")
    s = s.replace("🙃", "")
    s = s.replace("🤔", "")
    s = s.replace("😉", "")
    s = s.replace("⬇️", "")
    s = s.replace("🔴", "")
    s = s.replace("🤷‍", "")
    s = s.replace("🐞", "")
    s = s.replace("🚨", "")
    s = s.replace("🙌", "")
    s = s.replace("👑", "")
    s = s.replace("🔥", "")
    s = s.replace("👇", "")
    s = s.replace("👀", "")
    s = s.replace("/", "")
    s = s.replace("-", "")
    s = s.replace("\n", "")
    s = s.replace("https", "")
    s = s.replace("Covid19","COVID19")
    s = s.replace("covid19","COVID19")
    s = s.replace("coronavirus","COVID19")
    s = s.replace("CoronaVirus","COVID19")
    return str(s)

# %%
def clean_2(s):
    s = str(s).upper()
    s = s.replace("[", "")
    s = s.replace("]", "")
    s = s.replace("'", "")
    s = s.replace("CORONAVIRUS","COVID19")
    s = s.replace("CORONAVIRUS, COVID19","COVID19")
    s = s.replace("COVID19, COVID19","COVID19")
    
    return str(s).upper()

# %%
df["text_clean"] = ''
df["hashtags_clean"] = ''

# %%
for i, row in df.iterrows():
    df.at[i, "text_clean"] = clean_1(row.text)
    df.at[i, "hashtags_clean"] = clean_2(row.hashtags)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
for i, row in df.iterrows():
    if i % 1000 == 0:
        print(i)
    if(row["text_clean"] and len(str(row["text_clean"])) < 1000000):
        doc = nlp(str(row["text_clean"]))
        adjectives = []
        nouns = []
        verbs = []
        lemmas = []

        for token in doc:
            lemmas.append(token.lemma_)
            if token.pos_ == "ADJ":
                adjectives.append(token.lemma_)
            if token.pos_ == "NOUN" or token.pos_ == "PROPN":
                nouns.append(token.lemma_)
            if token.pos_ == "VERB":
                verbs.append(token.lemma_)
                
        df.at[i, "selftext_lemma"] = " ".join(lemmas)                
        df.at[i, "selftext_nouns"] = " ".join(nouns)
        df.at[i, "selftext_adjectives"] = " ".join(adjectives)
        df.at[i, "selftext_verbs"] = " ".join(verbs)
        df.at[i, "selftext_nav"] = " ".join(nouns+adjectives+verbs)
        df.at[i, "no_tokens"] = len(lemmas)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000

# %%
df['hashtags_clean'].nunique()
# Out:
# 21669

# %%
cat_df = df.groupby('hashtags_clean') \
           .agg({'user_location': pd.Series.nunique,
                 'user_name': pd.Series.count}) \
           .rename(columns={'user_location': 'num_locations',
                            'user_name': 'num_posts'}) \
           .sort_values('num_posts', ascending=False)
            
cat_df.head(5)
# Out:
#                                 num_locations  num_posts
# hashtags_clean
# NAN                                      5847      21434
# COVID19                                  5785      20747
# COVID19UPDATE, COVID19PANDEMIC              0        181
# COVID19UPDATES, COVID19                    43        163
# INDIAFIGHTSCORONA, COVID19                 35        113

# %%
cat_df.describe()
# Out:
#        num_locations     num_posts
# count   21669.000000  21669.000000
# mean        1.581891      3.435138
# std        55.889327    202.654735
# min         0.000000      1.000000
# 25%         1.000000      1.000000
# 50%         1.000000      1.000000
# 75%         1.000000      1.000000
# max      5847.000000  21434.000000

# %%
cat_df[['num_posts']].plot(kind='box', vert=False, figsize=(6, 2));

# %%
cat_df[['num_locations']][:20].plot(kind='bar');

# %%
cat_df[['num_locations']][2:20].plot(kind='bar');

# %%
sub_df = df[df['hashtags_clean']=='COVID19']


sub_df[['text_clean', 'selftext_nouns']].sample(2)
# Out:
#                                               text_clean  \
# 43128  So its safe enough to open schools and send fo...
# 37897  Watch  ER Doctor ‘We Are Not Overwhelming the ...
#
#                                           selftext_nouns
# 43128        school work covid19 election t.colHJpbY78Pg
# 37897  ER doctor Health Care System Lies COVID19 t.co...

# %%
def my_tokenizer(text):
    return text.split() if text != None else []

# %%
tokens = sub_df.selftext_nouns.map(my_tokenizer).sum()

# %%
from collections import Counter

counter = Counter(tokens)
counter.most_common(20)
# Out:
# [('COVID19', 12467),
#  ('covid19', 6672),
#  ('case', 3336),
#  ('death', 1422),
#  ('people', 1140),
#  ('pandemic', 740),
#  ('number', 684),
#  ('day', 654),
#  ('%', 601),
#  ('test', 593),
#  ('Coronavirus', 587),
#  ('today', 587),
#  ('country', 539),
#  ('mask', 539),
#  ('spread', 516),
#  ('India', 482),
#  ('time', 478),
#  ('state', 443),
#  ('risk', 439),
#  ('patient', 433)]

# %%
from spacy.lang.en.stop_words import STOP_WORDS

def remove_stopwords(tokens):
    """Remove stopwords from a list of tokens."""
    return [t for t in tokens if t not in STOP_WORDS]


counter = Counter(remove_stopwords(tokens))

# %%
freq_df = pd.DataFrame.from_records(counter.most_common(20),
                                    columns=['token', 'count'])


freq_df.plot(kind='bar', x='token');

# %%
from wordcloud import WordCloud

def wordcloud(counter):
    wc = WordCloud(width=1200, height=800, 
                   background_color="white", 
                   max_words=200) 
    wc.generate_from_frequencies(counter)

    # Plot
    fig=plt.figure(figsize=(6, 4))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

# %%
wordcloud(counter)

# %%
df['no_tokens'] = df.selftext_lemma\
  .map(lambda l: 0 if l==None else len(l.split()))

# %%
# mean number of tokens by category
prueba = df.groupby(['hashtags_clean']) \
  .agg({'no_tokens':'mean'}) \
  .sort_values(by='no_tokens', ascending=True);
prueba[:30].plot(kind='bar')

# %% [markdown]
# # Objetivo 2

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# 3             197           987             1488          False
# 4          101009           168              101          False
#
#                   date                                               text  \
# 0  2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1  2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2  2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3  2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4  2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
#
#    ...               source is_retweet  \
# 0  ...   Twitter for iPhone      False
# 1  ...  Twitter for Android      False
# 2  ...  Twitter for Android      False
# 3  ...   Twitter for iPhone      False
# 4  ...  Twitter for Android      False
#
#                                           text_clean           hashtags_clean  \
# 0  If I smelled the scent of hand sanitizers toda...                      NAN
# 1  Hey @Yankees @YankeesPR and @MLB  wouldnt it h...                      NAN
# 2  @diane3443 @wdunlap @realDonaldTrump Trump nev...                  COVID19
# 3  @brookbanktv The one gift COVID19 has give me ...                  COVID19
# 4  25 July  Media Bulletin on Novel COVID19Update...  COVID19UPDATES, COVID19
#
#                                       selftext_lemma  \
# 0  if -PRON- smell the scent of hand sanitizer to...
# 1  hey @Yankees @YankeesPR and @MLB   would not -...
# 2  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3  @brookbanktv the one gift COVID19 have give -P...
# 4  25 July   Media Bulletin on Novel COVID19Updat...
#
#                                       selftext_nouns selftext_adjectives  \
# 0                    scent hand sanitizer today past         intoxicated
# 1  @Yankees @YankeesPR @MLB sense player respect ...                more
# 2  @realDonaldTrump Trump COVID19 hoax effort t.c...
# 3     gift COVID19 appreciation thing t.coZ0pOAlFXcW              simple
# 4  July Media Bulletin Novel COVID19Updates covid...
#
#       selftext_verbs                                       selftext_nav  \
# 0  smell would think  scent hand sanitizer today past intoxicated sm...
# 1     would make pay  @Yankees @YankeesPR @MLB sense player respect ...
# 2        claim claim  @realDonaldTrump Trump COVID19 hoax effort t.c...
# 3               give  gift COVID19 appreciation thing t.coZ0pOAlFXcW...
# 4                     July Media Bulletin Novel COVID19Updates covid...
#
#   no_tokens
# 0        25
# 1        24
# 2        21
# 3        22
# 4        14
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        user_followers   user_friends  user_favourites     no_tokens
# count    7.443600e+04   74436.000000     7.443600e+04  74436.000000
# mean     1.059513e+05    2154.721170     1.529747e+04     19.765557
# std      8.222900e+05    9365.587474     4.668971e+04      5.179318
# min      0.000000e+00       0.000000     0.000000e+00      2.000000
# 25%      1.660000e+02     153.000000     2.200000e+02     17.000000
# 50%      9.600000e+02     552.000000     1.927000e+03     21.000000
# 75%      5.148000e+03    1780.250000     1.014800e+04     23.000000
# max      1.389284e+07  497363.000000     2.047197e+06     76.000000

# %%
df.describe(include=np.object).transpose()
# Out:
#                      count unique  \
# user_name            74436  44853
# user_location        59218  14622
# user_description     70079  42690
# user_created         74436  45554
# date                 74436  56546
# text                 74436  74312
# hashtags             53002  23445
# source               74424    450
# text_clean           74436  74310
# hashtags_clean       74436  21669
# selftext_lemma       74436  74310
# selftext_nouns       74436  71897
# selftext_adjectives  74436  23099
# selftext_verbs       74436  42128
# selftext_nav         74436  72472
#
#                                                                    top   freq
# user_name                                           GlobalPandemic.NET    312
# user_location                                                    India   1496
# user_description     Breaking News & Critical Information to SURVIV...    312
# user_created                                       2010-07-13 21:58:05    312
# date                                               2020-07-29 16:30:00     26
# text                 Greenland has no active cases of the novel cor...      6
# hashtags                                                   ['COVID19']  16004
# source                                                 Twitter Web App  22974
# text_clean           Greenland has no active cases of the novel COV...      6
# hashtags_clean                                                     NAN  21434
# selftext_lemma       Madhya Pradesh CM Shivraj Singh Chouhan say -P...      6
# selftext_nouns                      spread covid19 risk case symptom y    105
# selftext_adjectives                                                     24284
# selftext_verbs                                                           9245
# selftext_nav         spread covid19 risk case symptom y help slow i...    101

# %%
print(df.corr(method='pearson'))
# Out:
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
# no_tokens             -0.028507     -0.018386        -0.008034       0.023069
#
#                  is_retweet  no_tokens
# user_followers          NaN  -0.028507
# user_friends            NaN  -0.018386
# user_favourites         NaN  -0.008034
# user_verified           NaN   0.023069
# is_retweet              NaN        NaN
# no_tokens               NaN   1.000000

# %%
sns.pairplot(df)
plt.show()
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
columna_1 = df["user_followers"]
myData = [columna_1]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(myData) 
plt.title(" Boxplot User Followers") 
ax.set_xticklabels(['user_followers'])
plt.show()

# %%
columna_2 = df["user_friends"]
myData = [columna_2]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(myData) 
plt.title("Boxplot User Friends") 
ax.set_xticklabels(['user_friends'])
plt.show()

# %%
columna_3 = df["user_favourites"]
myData = [columna_3]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(myData) 
plt.title(" Boxplot User Favourites") 
ax.set_xticklabels(['user_favourites'])
plt.show()

# %%
#Boxplot general
columna_1 = df["user_followers"]
columna_2 = df["user_friends"]
columna_3 = df["user_favourites"]
myData = [columna_1,columna_2,columna_3]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(myData) 
plt.title("User Statistics Boxplot") 
ax.set_xticklabels(['user_followers', 'user_friends',  
                    'user_favourites']) 

plt.show()

# %%
#Histograma user_followers
np.random.seed(10**7) 
mu = 121 
sigma = 21
x = mu + sigma * np.random.randn(1000) 
   
num_bins = 100
   
n, bins, patches = plt.hist(df["user_followers"], num_bins,  
                            density = 1,  
                            color ='purple', 
                            alpha = 0.7) 
   
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) 
  
plt.plot(bins, y, '--', color ='black') 
  
plt.xlabel('X-Axis') 
plt.ylabel('Y-Axis') 
  
plt.title('User Followers', 
          fontweight ="bold") 
  
plt.show()

# %%
#Histograma user_friends
np.random.seed(10**7) 
mu = 121 
sigma = 21
x = mu + sigma * np.random.randn(1000) 
   
num_bins = 100
   
n, bins, patches = plt.hist(df["user_friends"], num_bins,  
                            density = 1,  
                            color ='orange', 
                            alpha = 0.7) 
   
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) 
  
plt.plot(bins, y, '--', color ='black') 
  
plt.xlabel('X-Axis') 
plt.ylabel('Y-Axis') 
  
plt.title('User Friends', 
          fontweight ="bold") 
  
plt.show()

# %%
#Histograma user_favourites
np.random.seed(10**7) 
mu = 121 
sigma = 21
x = mu + sigma * np.random.randn(1000) 
   
num_bins = 100
   
n, bins, patches = plt.hist(df["user_favourites"], num_bins,  
                            density = 1,  
                            color ='green', 
                            alpha = 0.7) 
   
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) 
  
plt.plot(bins, y, '--', color ='black') 
  
plt.xlabel('X-Axis') 
plt.ylabel('Y-Axis') 
  
plt.title('User Favourites', 
          fontweight ="bold") 
  
plt.show()

# %% [markdown]
# # Objetivo 3

# %%
dataframe = df.drop(['user_location','user_description','user_created','hashtags_clean','date','text','hashtags','source','is_retweet','text_clean','selftext_lemma','selftext_nouns','selftext_adjectives','selftext_verbs','selftext_nav','no_tokens'],axis=1)
dataframe.head()
# Out:
#          user_name  user_followers  user_friends  user_favourites  \
# 0           ᏉᎥ☻լꂅϮ             624           950            18775
# 1    Tom Basile 🇺🇸            2253          1677               24
# 2  Time4fisticuffs            9275          9525             7254
# 3      ethel mertz             197           987             1488
# 4         DIPR-J&K          101009           168              101
#
#    user_verified
# 0          False
# 1           True
# 2          False
# 3          False
# 4          False

# %%
dataframe.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
dataframe.groupby('user_verified')

# %%
dataframe.drop(['user_verified'],1).hist()
plt.show()

# %%
sb.pairplot(dataframe.dropna(), hue='user_verified',height=4,vars=["user_followers","user_friends","user_favourites"],kind='scatter')

# %%
X = np.array(dataframe[["user_followers","user_friends","user_favourites"]])
y = np.array(dataframe['user_verified'])
X.shape
# Out:
# (74436, 3)

# %%
fig = plt.figure()
ax = Axes3D(fig)
colores=['blue','red']
asignar=[]
for row in y:
    if(row=='False'):
        asignar.append(colores[1])
    else:
        asignar.append(colores[0])
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)

# %%
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
kmeans = KMeans(n_clusters=3).fit(X)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[3.11669314e+04 2.17082296e+03 1.54349135e+04]
#  [5.76923429e+06 7.11316832e+02 2.63207921e+03]
#  [1.30086912e+07 2.19937888e+02 8.03913043e+01]]

# %%
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','green','cyan']
asignar=[]
for row in labels:
    asignar.append(colores[row])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)

# %%
# Getting the values and plotting it
f1 = dataframe["user_followers"].values
f2 = dataframe["user_favourites"].values

plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.show()

# %%
f1 = dataframe["user_friends"].values
f2 = dataframe["user_favourites"].values

plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 2], marker='*', c=colores, s=1000)
plt.show()

# %%
f1 = dataframe["user_followers"].values
f2 = dataframe["user_friends"].values

plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 1], C[:, 2], marker='*', c=colores, s=1000)
plt.show()

# %%
copy =  pd.DataFrame()
copy['user_name']=dataframe['user_name'].values
copy['user_verified']=dataframe['user_verified'].values
copy['label'] = labels;
cantidadGrupo =  pd.DataFrame()
cantidadGrupo['color']=colores
cantidadGrupo['cantidad']=copy.groupby('label').size()
cantidadGrupo
# Out:
#    color  cantidad
# 0    red     73670
# 1  green       605
# 2   cyan       161

# %%
group_referrer_index = copy['label'] ==0
group_referrals = copy[group_referrer_index]

diversidadGrupo =  pd.DataFrame()
diversidadGrupo['user_verified']=['Non-verified','Verified']
diversidadGrupo['cantidad']=group_referrals.groupby('user_verified').size()
diversidadGrupo
# Out:
#   user_verified  cantidad
# 0  Non-verified     65079
# 1      Verified      8591

# %%
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, X)
closest
# Out:
# array([14321, 13688, 70675], dtype=int64)

# %%
users=dataframe['user_name'].values
for row in closest:
    print(users[row])
# Out:
# 🎗Christine Assange
# El Universal
# The Times Of India

# %%
newdf = df.drop(['user_name','user_verified','user_location','user_description','user_created','hashtags_clean','date','text','hashtags','source','is_retweet','text_clean','selftext_lemma','selftext_nouns','selftext_adjectives','selftext_verbs','selftext_nav','no_tokens'],axis=1)
newdf.head()
# Out:
#    user_followers  user_friends  user_favourites
# 0             624           950            18775
# 1            2253          1677               24
# 2            9275          9525             7254
# 3             197           987             1488
# 4          101009           168              101

# %%
grid_kws = {"height_ratios": (.9, .05), "hspace": .3} 
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax = sns.heatmap(newdf, cmap="YlGnBu", ax=ax, cbar_ax=cbar_ax, cbar_kws={"orientation": "horizontal"})
plt.show()
